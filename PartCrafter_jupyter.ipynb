# %% [markdown]
# ![819b915e-bd33-4ac1-89e1-a204fa3af42c.png](data:image/png;base64,...)

# %% [markdown]
# # Installation

# %%
# %cd /content
# !git clone -b dev https://github.com/harry2141985/PartCrafter.git
# %cd /content/PartCrafter
# !pip install -r requirements.txt

# !wget https://huggingface.co/spaces/alexnasa/PartCrafter/resolve/main/assets/images/np5_b81f29e567ea4db48014f89c9079e403.png -O /content/PartCrafter/assets/images/np5_b81f29e567ea4db48014f89c9079e403.png
# !wget https://huggingface.co/spaces/alexnasa/PartCrafter/resolve/main/assets/images/np7_1c004909dedb4ebe8db69b4d7b077434.png -O /content/PartCrafter/assets/images/np7_1c004909dedb4ebe8db69b4d7b077434.png
# !wget https://huggingface.co/spaces/alexnasa/PartCrafter/resolve/main/assets/images/np2_tree.png -O /content/PartCrafter/assets/images/np2_tree.png

# %% [markdown]
# # Launch with Gradio

# %%
# !python app.py
